# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\thisf\anaconda3\lib\site-packages (1.8.2)
# Requirement already satisfied: black>=24.10.0 in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (24.10.0)
# Requirement already satisfied: bleach in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: kagglesdk in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (0.1.13)
# Requirement already satisfied: mypy>=1.15.0 in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: protobuf in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (5.29.3)
# Requirement already satisfied: python-dateutil in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (72.1.0)
# Requirement already satisfied: six>=1.10 in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: types-requests in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\thisf\anaconda3\lib\site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\thisf\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\thisf\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\thisf\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (24.2)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\thisf\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\thisf\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (4.3.7)
# Requirement already satisfied: colorama in c:\users\thisf\anaconda3\lib\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\thisf\anaconda3\lib\site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in c:\users\thisf\anaconda3\lib\site-packages (from mypy>=1.15.0->kaggle) (0.7.4)
# Requirement already satisfied: webencodings in c:\users\thisf\anaconda3\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\thisf\anaconda3\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thisf\anaconda3\lib\site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thisf\anaconda3\lib\site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thisf\anaconda3\lib\site-packages (from requests->kaggle) (2025.11.12)

# %%
import kaggle

# %%
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# Downloading orders.csv.zip to C:\Users\thisf\Desktop\Cloud Data Engineer\project
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:02<00:00, 98.6kB/s]
# 100%|##########| 200k/200k [00:02<00:00, 98.5kB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('orders.csv.zip') 
zip_ref.extractall() # extract file to dir
zip_ref.close() # close file

# %%
import pandas as pd
df = pd.read_csv('orders.csv',na_values=['Not Available','unknown'])
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df.head(5)
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# 1       Chairs  FUR-CH-10000454         600         730         3
# 2       Labels  OFF-LA-10000240          10          10         2
# 3       Tables  FUR-TA-10000577         780         960         5
# 4      Storage  OFF-ST-10000760          20          20         2
#
#    Discount Percent
# 0                 2
# 1                 3
# 2                 5
# 3                 2
# 4                 5

# %%
df.rename(columns={'Order Id':'order_id', 'City':'city'})
df.head(3)
# Out:
#    order_id  order_date     ship_mode    segment        country         city  \
# 0         1  2023-03-01  Second Class   Consumer  United States    Henderson
# 1         2  2023-08-15  Second Class   Consumer  United States    Henderson
# 2         3  2023-01-10  Second Class  Corporate  United States  Los Angeles
#
#         state  postal_code region         category sub_category  \
# 0    Kentucky        42420  South        Furniture    Bookcases
# 1    Kentucky        42420  South        Furniture       Chairs
# 2  California        90036   West  Office Supplies       Labels
#
#         product_id  cost_price  list_price  quantity  discount_percent  \
# 0  FUR-BO-10001798         240         260         2                 2
# 1  FUR-CH-10000454         600         730         3                 3
# 2  OFF-LA-10000240          10          10         2                 5
#
#    discount  sale_price  profit
# 0       5.2       254.8    14.8
# 1      21.9       708.1   108.1
# 2       0.5         9.5    -0.5

# %%
df.columns=df.columns.str.lower()
df.head(3)
# Out:
#    order_id  order_date     ship_mode    segment        country         city  \
# 0         1  2023-03-01  Second Class   Consumer  United States    Henderson
# 1         2  2023-08-15  Second Class   Consumer  United States    Henderson
# 2         3  2023-01-10  Second Class  Corporate  United States  Los Angeles
#
#         state  postal_code region         category sub_category  \
# 0    Kentucky        42420  South        Furniture    Bookcases
# 1    Kentucky        42420  South        Furniture       Chairs
# 2  California        90036   West  Office Supplies       Labels
#
#         product_id  cost_price  list_price  quantity  discount_percent  \
# 0  FUR-BO-10001798         240         260         2                 2
# 1  FUR-CH-10000454         600         730         3                 3
# 2  OFF-LA-10000240          10          10         2                 5
#
#    discount  sale_price  profit
# 0       5.2       254.8    14.8
# 1      21.9       708.1   108.1
# 2       0.5         9.5    -0.5

# %%
df.columns=df.columns.str.replace(' ','_')
df.head(3)
# Out:
#    order_id  order_date     ship_mode    segment        country         city  \
# 0         1  2023-03-01  Second Class   Consumer  United States    Henderson
# 1         2  2023-08-15  Second Class   Consumer  United States    Henderson
# 2         3  2023-01-10  Second Class  Corporate  United States  Los Angeles
#
#         state  postal_code region         category sub_category  \
# 0    Kentucky        42420  South        Furniture    Bookcases
# 1    Kentucky        42420  South        Furniture       Chairs
# 2  California        90036   West  Office Supplies       Labels
#
#         product_id  cost_price  list_price  quantity  discount_percent  \
# 0  FUR-BO-10001798         240         260         2                 2
# 1  FUR-CH-10000454         600         730         3                 3
# 2  OFF-LA-10000240          10          10         2                 5
#
#    discount  sale_price  profit
# 0       5.2       254.8    14.8
# 1      21.9       708.1   108.1
# 2       0.5         9.5    -0.5

# %%
df['discount']=df['list_price']*df['discount_percent']*.01
df.head(3)
# Out:
#    order_id  order_date     ship_mode    segment        country         city  \
# 0         1  2023-03-01  Second Class   Consumer  United States    Henderson
# 1         2  2023-08-15  Second Class   Consumer  United States    Henderson
# 2         3  2023-01-10  Second Class  Corporate  United States  Los Angeles
#
#         state  postal_code region         category sub_category  \
# 0    Kentucky        42420  South        Furniture    Bookcases
# 1    Kentucky        42420  South        Furniture       Chairs
# 2  California        90036   West  Office Supplies       Labels
#
#         product_id  cost_price  list_price  quantity  discount_percent  \
# 0  FUR-BO-10001798         240         260         2                 2
# 1  FUR-CH-10000454         600         730         3                 3
# 2  OFF-LA-10000240          10          10         2                 5
#
#    discount  sale_price  profit
# 0       5.2       254.8    14.8
# 1      21.9       708.1   108.1
# 2       0.5         9.5    -0.5

# %%
df['sale_price']= df['list_price']-df['discount']
df.head(3)
# Out:
#    order_id  order_date     ship_mode    segment        country         city  \
# 0         1  2023-03-01  Second Class   Consumer  United States    Henderson
# 1         2  2023-08-15  Second Class   Consumer  United States    Henderson
# 2         3  2023-01-10  Second Class  Corporate  United States  Los Angeles
#
#         state  postal_code region         category sub_category  \
# 0    Kentucky        42420  South        Furniture    Bookcases
# 1    Kentucky        42420  South        Furniture       Chairs
# 2  California        90036   West  Office Supplies       Labels
#
#         product_id  cost_price  list_price  quantity  discount_percent  \
# 0  FUR-BO-10001798         240         260         2                 2
# 1  FUR-CH-10000454         600         730         3                 3
# 2  OFF-LA-10000240          10          10         2                 5
#
#    discount  sale_price  profit
# 0       5.2       254.8    14.8
# 1      21.9       708.1   108.1
# 2       0.5         9.5    -0.5

# %%
df['profit']=df['sale_price']-df['cost_price']
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# 1       Chairs  FUR-CH-10000454         600         730         3
# 2       Labels  OFF-LA-10000240          10          10         2
# 3       Tables  FUR-TA-10000577         780         960         5
# 4      Storage  OFF-ST-10000760          20          20         2
#
#    discount_percent  discount  sale_price  profit
# 0                 2       5.2       254.8    14.8
# 1                 3      21.9       708.1   108.1
# 2                 5       0.5         9.5    -0.5
# 3                 2      19.2       940.8   160.8
# 4                 5       1.0        19.0    -1.0

# %%
df['order_date']=pd.to_datetime(df['order_date'],format="%Y-%m-%d")
df.head(3)
# Out:
#    order_id order_date     ship_mode    segment        country         city  \
# 0         1 2023-03-01  Second Class   Consumer  United States    Henderson
# 1         2 2023-08-15  Second Class   Consumer  United States    Henderson
# 2         3 2023-01-10  Second Class  Corporate  United States  Los Angeles
#
#         state  postal_code region         category sub_category  \
# 0    Kentucky        42420  South        Furniture    Bookcases
# 1    Kentucky        42420  South        Furniture       Chairs
# 2  California        90036   West  Office Supplies       Labels
#
#         product_id  cost_price  list_price  quantity  discount_percent  \
# 0  FUR-BO-10001798         240         260         2                 2
# 1  FUR-CH-10000454         600         730         3                 3
# 2  OFF-LA-10000240          10          10         2                 5
#
#    discount  sale_price  profit
# 0       5.2       254.8    14.8
# 1      21.9       708.1   108.1
# 2       0.5         9.5    -0.5

# %%
#drop cost price list price and discount percent columns
df.drop(columns=['list_price','cost_price','discount_percent'],inplace=True)
df.head(3)
# Out:
#    order_id order_date     ship_mode    segment        country         city  \
# 0         1 2023-03-01  Second Class   Consumer  United States    Henderson
# 1         2 2023-08-15  Second Class   Consumer  United States    Henderson
# 2         3 2023-01-10  Second Class  Corporate  United States  Los Angeles
#
#         state  postal_code region         category sub_category  \
# 0    Kentucky        42420  South        Furniture    Bookcases
# 1    Kentucky        42420  South        Furniture       Chairs
# 2  California        90036   West  Office Supplies       Labels
#
#         product_id  quantity  discount  sale_price  profit
# 0  FUR-BO-10001798         2       5.2       254.8    14.8
# 1  FUR-CH-10000454         3      21.9       708.1   108.1
# 2  OFF-LA-10000240         2       0.5         9.5    -0.5

# %%
from matplotlib import pyplot as plt

# %%
#load the data into sql server using replace option
import sqlalchemy as sal
engine = sal.create_engine('mssql://DESKTOP-PI1U0J8/master?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn=engine.connect()

# %%
#load the data into sql server using append option
df.to_sql('df_orders', con=conn , index=False, if_exists = 'append')
# Out:
# 38
